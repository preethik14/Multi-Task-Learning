# %%
import numpy as np
import pandas as pd 
import os

# %%
for dirname, _, filenames in os.walk('C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\crap.xls
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database.rar
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\IXI002-Guys-0828-T1.nii_fast_out_restore.nii_registered.nii
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\New Microsoft Excel Worksheet.xlsx
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\TST1.CSV
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\demographic_info_icbhi.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\filename_differences.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\filename_format.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\New Microsoft Excel Worksheet.xlsx
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\patient_diagnosis.csv
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\wheezes_crackles_diagnosis (1).csv
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\101_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\101_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\102_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\104_1b1_Al_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\104_1b1_Ar_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\104_1b1_Ll_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\104_1b1_Lr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\104_1b1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\104_1b1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\105_1b1_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\106_2b1_Pl_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\106_2b1_Pr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b5_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b5_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b5_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b5_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b5_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b5_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_2b5_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_3p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_3p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_3p2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_3p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_3p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_3p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\107_3p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\109_1b1_Al_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\109_1b1_Ar_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\109_1b1_Ll_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\109_1b1_Lr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\109_1b1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\109_1b1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\110_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\110_1p1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\110_1p1_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\110_1p1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\110_1p1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\111_1b2_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\111_1b3_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\112_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\112_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\112_1p1_Ll_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\112_1p1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\112_1p1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\113_1b1_Al_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\113_1b1_Ar_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\113_1b1_Ll_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\113_1b1_Lr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\113_1b1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\113_1b1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\114_1b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\114_1b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\114_1b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\114_1b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\114_1b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\116_1b2_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\116_1b2_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\117_1b2_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\117_1b3_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\118_1b1_Al_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\118_1b1_Ar_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\118_1b1_Ll_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\118_1b1_Lr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\118_1b1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\118_1b1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\119_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\120_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\120_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\120_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\120_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\120_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\121_1b1_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\121_1p1_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b1_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b1_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b1_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b2_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b2_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b2_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b3_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b3_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\122_2b3_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\123_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\124_1b1_Al_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\124_1b1_Ar_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\124_1b1_Ll_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\124_1b1_Lr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\124_1b1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\124_1b1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\125_1b1_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\126_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\127_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\128_1b3_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\129_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_1p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2p5_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2p5_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2p5_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2p5_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2p5_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_2p5_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\130_3p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\131_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\132_2b1_Lr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\132_2b2_Lr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_2p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_3p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_3p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_3p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_3p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\133_3p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\134_2b1_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\134_2b1_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\134_2b2_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\134_2b2_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\134_2b3_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b1_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b1_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b1_Pl_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b1_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b2_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b2_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b2_Pl_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b2_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b3_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b3_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b3_Pl_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b3_Pr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\135_2b3_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\136_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\137_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\137_1b1_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_1p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_2p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_2p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_2p2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_2p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_2p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_2p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\138_2p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\139_1b1_Al_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\139_1b1_Ar_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\139_1b1_Ll_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\139_1b1_Lr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\139_1b1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\139_1b1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\140_2b2_Ll_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\140_2b2_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\140_2b3_Ll_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\140_2b3_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b1_Pr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b2_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b2_Lr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b2_Pr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b2_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b3_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b3_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\141_1b3_Pr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\142_1b1_Pl_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\143_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\144_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\144_1b1_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\145_2b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\145_2b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\145_2b2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\145_2b2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\145_3b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\145_3b2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\145_3b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_2b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_2b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_2b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_2b4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_2b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_2b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_8p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_8p3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_8p3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_8p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\146_8p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_1b2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_1b3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_1b4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\147_2b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\148_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\149_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\149_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\149_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\150_1b2_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_2p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_3p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_3p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_3p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_3p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_3p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_3p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\151_3p3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\152_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\153_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_1b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_1b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_1b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_1b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_1b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_1b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_1b3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_2b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_2b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_2b4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_2b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_2b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_2b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_2b4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_3b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_3b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_3b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_4b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_4b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_4b4_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_4b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_4b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\154_4b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\155_2b1_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_2b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_2b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_2b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_2b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_2b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_2b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_5b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_5b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_5b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_5b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_5b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_5b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_8b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_8b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_8b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_8b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\156_8b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\157_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\157_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\157_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\157_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\157_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1b3_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_1p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_2p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_2p3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\158_2p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\159_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\159_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\159_1b1_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\159_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_1b4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_2b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_2b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_2b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_2b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\160_2b4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\161_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\161_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_1b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_1b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_1b2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_1b2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_1b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_1b2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_1b2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\162_2b4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_2b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_2b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_2b2_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_2b2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_2b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_2b2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_2b2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_8b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_8b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_8b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_8b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_8b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\163_8b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\164_1b1_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\165_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\165_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\165_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\166_1p1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\166_1p1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\166_1p1_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\166_1p1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\166_1p1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\167_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\167_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\168_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\169_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\169_1b2_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b3_Ll_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b3_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b4_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b4_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b4_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b4_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b4_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_1b4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_2b2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\20s\170_2b2_Ar_mc_AKGC417L.wav
# ...
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\211_2p2_Tc_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\211_2p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\211_2p3_Tc_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\211_2p3_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\211_2p4_Tc_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\211_2p4_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\212_2b2_Tc_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\212_2b2_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Al_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Ar_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Lr_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Lr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Pl_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Pr_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Tc_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Al_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Ar_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Pl_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Pr_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p3_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Al_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Ar_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Pl_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Pr_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Tc_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_1p5_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Al_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Al_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Ar_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Ar_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Pl_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Pl_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Pr_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Pr_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Tc_mc_AKGC417L.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\213_2p2_Tc_mc_AKGC417L.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\214_1b1_Ar_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\214_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\215_1b2_Ar_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\215_1b2_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\215_1b3_Tc_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\215_1b3_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\216_1b1_Al_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\216_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\216_1b1_Pl_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\216_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\217_1b1_Tc_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\217_1b1_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Al_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Ar_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Lr_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Pl_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Pr_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1p1_Ar_sc_Litt3200.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1p1_Ar_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1p1_Pl_sc_Litt3200.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1p1_Pl_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1p1_Pr_sc_Litt3200.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\218_1p1_Pr_sc_Litt3200.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b1_Ar_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b1_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b1_Tc_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b1_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b2_Ar_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b2_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b2_Tc_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b2_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b3_Tc_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\219_2b3_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\220_1b1_Tc_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\220_1b1_Tc_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\220_1b2_Al_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\220_1b2_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Al_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Ar_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Lr_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Lr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Pl_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b1_Pl_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Al_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Ar_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Lr_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Lr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Pl_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b2_Pl_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Al_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Al_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Ar_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Ar_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Lr_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Lr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Pr_mc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\221_2b3_Pr_mc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\222_1b1_Ar_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\222_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\222_1b1_Lr_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\222_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\222_1b1_Pr_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\222_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Al_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Ar_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Ar_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Ll_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Lr_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Lr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Pl_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Pr_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\223_1b1_Pr_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\224_1b1_Tc_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\224_1b1_Tc_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\224_1b2_Al_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\224_1b2_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\225_1b1_Pl_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\225_1b1_Pl_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\226_1b1_Al_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\226_1b1_Al_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\226_1b1_Ll_sc_Meditron.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\226_1b1_Ll_sc_Meditron.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\226_1b1_Pl_sc_LittC2SE.txt
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\ICBHI_final_database\audio_and_txt_files\226_1b1_Pl_sc_LittC2SE.wav
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\risk\normal high updated.csv
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\risk\risk factors all column.xlsx
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\risk\risk_final.csv
# C:\Users\LENOVO\OneDrive\Desktop\Dataset\risk\risk_final_noise.csv

# %%
from datetime import datetime
from os import listdir
from os.path import isfile, join

import librosa
import librosa.display

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import savefig

# %%
mypath = "C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\audio_and_txt_files"
filenames = [f for f in listdir(mypath) if (isfile(join(mypath, f)) and f.endswith('.wav'))] 
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file) 
print(p_id_in_file)
# Out:
# [101 101 102 103 104 104 104 104 104 104 105 106 106 107 107 107 107 107
#  107 107 107 107 107 107 107 107 107 107 107 107 107 107 107 107 107 107
#  107 107 107 107 107 109 109 109 109 109 109 110 110 110 110 110 111 111
#  112 112 112 112 112 113 113 113 113 113 113 114 114 114 114 114 116 116
#  117 117 118 118 118 118 118 118 119 120 120 120 120 120 121 121 122 122
#  122 122 122 122 122 122 122 123 124 124 124 124 124 124 125 126 127 128
#  129 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130
#  130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130
#  130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130 130
#  130 130 130 130 130 130 130 130 130 130 130 130 130 131 132 132 133 133
#  133 133 133 133 133 133 133 133 133 133 133 133 133 133 133 133 133 134
#  134 134 134 134 135 135 135 135 135 135 135 135 135 135 135 135 135 136
#  137 137 138 138 138 138 138 138 138 138 138 138 138 138 138 138 138 138
#  138 138 138 138 138 138 138 138 138 138 138 139 139 139 139 139 139 140
#  140 140 140 141 141 141 141 141 141 141 141 142 143 144 144 145 145 145
#  145 145 145 145 146 146 146 146 146 146 146 146 146 146 146 147 147 147
#  147 147 147 147 147 147 147 147 147 147 147 147 147 148 149 149 149 150
#  151 151 151 151 151 151 151 151 151 151 151 151 151 151 151 151 151 151
#  151 151 151 151 151 151 151 151 151 151 152 153 154 154 154 154 154 154
#  154 154 154 154 154 154 154 154 154 154 154 154 154 154 154 154 154 155
#  156 156 156 156 156 156 156 156 156 156 156 156 156 156 156 156 156 157
#  157 157 157 157 158 158 158 158 158 158 158 158 158 158 158 158 158 158
#  158 158 158 158 158 158 158 158 158 158 159 159 159 159 160 160 160 160
#  160 160 160 160 160 160 160 160 160 160 160 160 160 160 160 160 160 160
#  160 161 161 162 162 162 162 162 162 162 162 162 162 162 162 162 162 162
#  162 162 162 162 162 162 162 162 162 163 163 163 163 163 163 163 163 163
#  163 163 163 163 164 165 165 165 166 166 166 166 166 167 167 168 169 169
#  170 170 170 170 170 170 170 170 170 170 170 170 170 170 170 170 170 170
#  170 170 170 170 170 170 170 171 172 172 172 172 172 172 172 172 172 172
#  172 172 172 172 172 172 172 172 172 172 172 172 172 172 172 172 172 173
#  174 174 174 174 174 174 174 174 174 174 174 174 174 174 174 174 174 174
#  174 174 174 174 174 175 175 175 175 175 175 176 176 176 176 176 176 176
#  176 176 176 176 176 176 176 176 176 176 176 176 176 176 177 177 177 177
#  177 177 177 177 177 177 177 177 177 177 177 177 177 178 178 178 178 178
#  178 178 178 178 178 178 178 178 178 178 178 178 178 178 178 178 178 178
#  178 179 179 180 180 180 180 180 181 181 181 181 182 183 183 184 185 185
#  185 185 185 185 186 186 186 186 186 186 186 186 186 186 186 186 186 186
#  186 186 186 186 186 186 186 186 186 186 187 188 188 188 188 189 190 191
#  191 191 192 192 192 192 192 192 193 193 193 193 193 193 193 193 193 193
#  193 193 193 193 194 194 195 195 195 195 195 195 196 197 197 198 198 198
#  198 198 198 198 198 198 198 198 198 198 198 199 199 200 200 200 200 200
#  200 200 200 200 200 200 200 200 200 200 200 200 200 200 200 200 200 200
#  201 201 201 201 201 201 202 203 203 203 203 203 203 203 203 203 203 203
#  203 203 203 203 203 203 203 203 203 203 204 204 204 204 204 204 204 204
#  204 205 205 205 205 205 205 205 205 205 205 205 205 205 205 205 205 205
#  205 205 205 206 206 206 207 207 207 207 207 207 207 207 207 207 207 207
#  207 207 207 207 207 207 207 207 207 208 209 210 210 211 211 211 211 211
#  211 211 211 212 213 213 213 213 213 213 213 213 213 213 213 213 213 213
#  213 213 213 213 213 213 214 215 215 216 216 217 218 218 218 218 218 218
#  218 218 219 219 219 219 219 220 220 221 221 221 221 221 221 221 221 221
#  221 221 221 222 222 222 223 223 223 223 223 223 224 224 225 226 226 226]

# %%
max_pad_len = 862 

def extract_features(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=20) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        print(f"Error details: {str(e)}")
        return None 
     
    return mfccs
mypath = "C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\audio_and_txt_files"
filepaths = [os.path.join(mypath, f) for f in filenames]

#filepaths = [join(mypath, f) for f in filenames]
p_diag1 = pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\patient_diagnosis.csv",header=None)
p_diag2 = pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\wheezes_crackles_diagnosis (1).csv",header=None)


disease_labels = np.array([p_diag1[p_diag1[0] == x][1].values[0] for x in p_id_in_file])
sound_labels = np.array([p_diag2[p_diag2[0] == x][1].values[0] for x in p_id_in_file])
features = [] 

for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 24
#      20 p_diag1 = pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\patient_diagnosis.csv",header=None)
#      21 p_diag2 = pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\wheezes_crackles_diagnosis (1).csv",header=None)
# ---> 24 disease_labels = np.array([p_diag1[p_diag1[0] == x][1].values[0] for x in p_id_in_file])
#      25 sound_labels = np.array([p_diag2[p_diag2[0] == x][1].values[0] for x in p_id_in_file])
#      26 features = []
#
# Cell In[5], line 24, in <listcomp>(.0)
#      20 p_diag1 = pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\patient_diagnosis.csv",header=None)
#      21 p_diag2 = pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Dataset\\ICBHI_final_database\\wheezes_crackles_diagnosis (1).csv",header=None)
# ---> 24 disease_labels = np.array([p_diag1[p_diag1[0] == x][1].values[0] for x in p_id_in_file])
#      25 sound_labels = np.array([p_diag2[p_diag2[0] == x][1].values[0] for x in p_id_in_file])
#      26 features = []
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis= 'time')
plt.xlabel('Time(seconds)', fontsize=18)
plt.rc('xtick', labelsize=13)
plt.colorbar()
plt.title('MFCC', fontsize=20)
plt.rc('ytick', labelsize=13)
plt.tight_layout()
plt.savefig('plot1.eps', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.figure(figsize=(10, 4))
# ----> 2 librosa.display.specshow(features[7], x_axis= 'time')
#       3 plt.xlabel('Time(seconds)', fontsize=18)
#       4 plt.rc('xtick', labelsize=13)
#
# NameError: name 'features' is not defined

# %%
features = np.array(features)
#features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI'))[0], axis=0) 
#disease_labels1 = np.delete(disease_labels, np.where((labels == 'Asthma') | (labels == 'LRTI'))[0], axis=0)
print(features)

# %%
unique_elements, counts_elements = np.unique(disease_labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
unique_elements1, counts_elements1 = np.unique(sound_labels, return_counts=True)
print(np.asarray((unique_elements1, counts_elements1)))

# %%
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count', fontsize=21)
plt.rc('ytick', labelsize=15)
plt.xlabel('Disease', fontsize=21)
plt.rc('xtick', labelsize=14.99)
plt.title('Disease Count in Sound Files', fontsize=23)
plt.savefig('plot2.eps', dpi=300, bbox_inches='tight')
plt.show()

# %%
y_pos = np.arange(len(unique_elements1))
plt.figure(figsize=(12,8))
plt.bar(unique_elements1, counts_elements1, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements1)
plt.ylabel('Count', fontsize=21)
plt.rc('ytick', labelsize=15)
plt.xlabel('Sound', fontsize=21)
plt.rc('xtick', labelsize=14.99)
plt.title('Sound Count in Sound Files', fontsize=23)
plt.savefig('plot2.eps', dpi=300, bbox_inches='tight')
plt.show()

# %%
le = LabelEncoder()
i_labels = le.fit_transform(disease_labels)
le1 = LabelEncoder()
i_labels1 = le1.fit_transform(sound_labels)
oh_labels = to_categorical(i_labels)
oh_labels1 = to_categorical(i_labels1)
features1 = np.reshape(features, (*features.shape,1)) 
features2 = np.reshape(features, (*features.shape,1))

# %%
x_train_disease, x_test_disease, y_train_disease, y_test_disease = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)
x_train_sound, x_test_sound, y_train_sound, y_test_sound = train_test_split(features2, oh_labels1, stratify=oh_labels1, 
                                                    test_size=0.2, random_state = 42)

num_rows = 40
num_columns = 862
num_channels = 1
num_labels_disease = 6
num_labels_sound = 4

filter_size = 2

# %%
#x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, 
                                                    #test_size=0.2, random_state = 42)
from keras.layers import Input
num_rows = 40
num_columns = 862
num_channels = 1
'''
num_labels = oh_labels.shape[1]
num_labels1 = oh_labels1.shape[1]
filter_size = 2
'''
# Assuming num_classes_sound and num_classes_disease are the number of classes for sound and disease predictions
#num_classes_sound = oh_labels_sound.shape[4]
#num_classes_disease = oh_labels_disease.shape[8]

# Create input layer for common features
#input_shape_common = (num_frames, num_features_common)
#input_common = Input(shape=input_shape_common, name='input_common')

# Assuming you have sound and disease labels
num_labels_sound = 4
num_labels_disease = 6

# Input shape for sound data
input_shape_sound = (num_rows, num_columns, num_channels)  # Adjust based on your sound data shape

# Input shape for disease data
input_shape_disease = (num_rows, num_columns, num_channels)  # Adjust based on your disease data shape

# Filter size
filter_size = 2

# Create separate input layers for sound and disease data
input_sound = Input(shape=input_shape_sound, name='input_sound')
input_disease = Input(shape=input_shape_disease, name='input_disease')

# %%
from tensorflow.keras.layers import Input, Conv2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense, concatenate
from tensorflow.keras.models import Model

# Define input layers
#input_sound = Input(shape=(224, 224, 3), name='input_sound')
#input_disease = Input(shape=(224, 224, 3), name='input_disease')

# Function for bottleneck block
def bottleneck_block(x, filters, kernel_size=3, strides=1):
    # Depthwise separable convolution
    x = DepthwiseConv2D(kernel_size, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    # Pointwise convolution
    x = Conv2D(filters, kernel_size=1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    return x

# Apply bottleneck blocks to input_sound
x1 = Conv2D(32, kernel_size=3, strides=2, padding='same')(input_sound)
x1 = bottleneck_block(x1, filters=32)
x1 = bottleneck_block(x1, filters=64)
x1 = bottleneck_block(x1, filters=128)
x1 = bottleneck_block(x1, filters=256)
x1 = Conv2D(32, kernel_size=3, strides=2, padding='same')(x1)
x1 = bottleneck_block(x1, filters=256)
global_avg_pooling_sound = GlobalAveragePooling2D()(x1)

# Apply bottleneck blocks to input_disease
x2 = Conv2D(32, kernel_size=3, strides=2, padding='same')(input_disease)
x2 = bottleneck_block(x2, filters=32)
x2 = bottleneck_block(x2, filters=64)
x2 = bottleneck_block(x2, filters=128)
x2 = bottleneck_block(x2, filters=256)
x2 = Conv2D(32, kernel_size=3, strides=2, padding='same')(x2)
x2 = bottleneck_block(x2, filters=256)
global_avg_pooling_disease = GlobalAveragePooling2D()(x2)

# Concatenate global average pooling layers
merged = concatenate([global_avg_pooling_sound, global_avg_pooling_disease])

# Dense layers for the merged features
dense_merged = Dense(256, activation='relu')(merged)

# Output layers for sound and disease predictions
output_sound = Dense(num_labels_sound, activation='softmax', name='sound_output')(dense_merged)
output_disease = Dense(num_labels_disease, activation='softmax', name='disease_output')(dense_merged)

# Create the model
model = Model(inputs=[input_sound, input_disease], outputs=[output_sound, output_disease])

# Compile the model with appropriate loss functions for each output
model.compile(optimizer='adam', loss={'sound_output': 'categorical_crossentropy', 'disease_output': 'categorical_crossentropy'}, metrics=['accuracy'])

# %%
model.summary()

# %%
history = model.fit(
    [x_train_sound, x_train_disease],  # Input features for sound and disease
    {'sound_output': y_train_sound, 'disease_output': y_train_disease},  # Output labels for sound and disease
    epochs=1,
    batch_size=32,
    validation_split=0.2
)

# %%
# Evaluate training accuracy for sound and disease
train_scores = model.evaluate([x_train_sound, x_train_disease], {'sound_output': y_train_sound, 'disease_output': y_train_disease}, verbose=0)
print("Training Accuracy - Sound: ", train_scores[3])  # Assuming sound_output is the 7th index
print("Training Accuracy - Disease: ", train_scores[4])  # Assuming disease_output is the 8th index

# Evaluate testing accuracy for sound and disease
test_scores = model.evaluate([x_test_sound, x_test_disease], {'sound_output': y_test_sound, 'disease_output': y_test_disease}, verbose=0)
print("Testing Accuracy - Sound: ", test_scores[2])  # Assuming sound_output is the 7th index
print("Testing Accuracy - Disease: ", test_scores[4])  # Assuming disease_output is the 8th index

# %%
preds_sound, preds_disease = model.predict([x_test_sound, x_test_disease])

classpreds_sound = np.argmax(preds_sound, axis=1)
y_testclass_sound = np.argmax(y_test_sound, axis=1)

classpreds_disease = np.argmax(preds_disease, axis=1)
y_testclass_disease = np.argmax(y_test_disease, axis=1)

# %%
from sklearn.metrics import classification_report

c_names_disease = ['Bronchiolitis', 'Bronchiectasis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
c_names_sound =  ['Crackles', 'Healthy', 'Wheezes', 'Wheezes & Crackles']
# Assuming preds_sound and preds_disease are the predictions for sound and disease
classpreds_sound = np.argmax(preds_sound, axis=1)
y_testclass_sound = np.argmax(y_test_sound, axis=1)

classpreds_disease = np.argmax(preds_disease, axis=1)
y_testclass_disease = np.argmax(y_test_disease, axis=1)

# Print classification report for sound
print("Classification Report - Sound:")
print(classification_report(y_testclass_sound, classpreds_sound, target_names=c_names_sound))

# Print classification report for disease
print("Classification Report - Disease:")
print(classification_report(y_testclass_disease, classpreds_disease, target_names=c_names_disease))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Assuming classpreds_sound and classpreds_disease are the predicted classes for sound and disease
cm_sound = confusion_matrix(y_testclass_sound, classpreds_sound)
disp_sound = ConfusionMatrixDisplay(confusion_matrix=cm_sound, display_labels=c_names_sound)

cm_disease = confusion_matrix(y_testclass_disease, classpreds_disease)
disp_disease = ConfusionMatrixDisplay(confusion_matrix=cm_disease, display_labels=c_names_disease)

# Plot confusion matrix for sound
disp_sound.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - Sound')
plt.show()

# Plot confusion matrix for disease
disp_disease.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - Disease')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Assuming preds_sound and preds_disease are the predictions for sound and disease
fpr_sound = dict()
tpr_sound = dict()
roc_auc_sound = dict()

fpr_disease = dict()
tpr_disease = dict()
roc_auc_disease = dict()

# ROC curve and AUC for sound
for i in range(num_labels_sound):
    fpr_sound[i], tpr_sound[i], _ = roc_curve(y_test_sound[:, i], preds_sound[:, i])
    roc_auc_sound[i] = auc(fpr_sound[i], tpr_sound[i])

# ROC curve and AUC for disease
for i in range(num_labels_disease):
    fpr_disease[i], tpr_disease[i], _ = roc_curve(y_test_disease[:, i], preds_disease[:, i])
    roc_auc_disease[i] = auc(fpr_disease[i], tpr_disease[i])

# Plot ROC curves for sound
plt.figure(figsize=(10, 6))
for i in range(num_labels_sound):
    plt.plot(fpr_sound[i], tpr_sound[i], label=f'Sound Class {i} (AUC = {roc_auc_sound[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Diagonal line for reference
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Sound')
plt.legend(loc="lower right")
plt.show()

# Plot ROC curves for disease
plt.figure(figsize=(10, 6))
for i in range(num_labels_disease):
    plt.plot(fpr_disease[i], tpr_disease[i], label=f'Disease Class {i} (AUC = {roc_auc_disease[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Diagonal line for reference
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Disease')
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.title('Sound Accuracy Curve', fontsize=19)
plt.plot(history.history['sound_output_accuracy'], label='training acc')
plt.plot(history.history['val_sound_output_accuracy'], label='validation acc')
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.legend(fontsize=12)

plt.subplot(1, 2, 2)
plt.title('Disease Accuracy Curve', fontsize=19)
plt.plot(history.history['disease_output_accuracy'], label='training acc')
plt.plot(history.history['val_disease_output_accuracy'], label='validation acc')
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.xlabel('Epochs ', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

# Sound model loss curve
plt.subplot(1, 2, 1)
plt.plot(history.history['sound_output_loss'], label='training loss')
plt.plot(history.history['val_sound_output_loss'], label='validation loss')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(fontsize=12)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
plt.title('Sound Loss Curve', fontsize=19)

# Disease model loss curve
plt.subplot(1, 2, 2)
plt.plot(history.history['disease_output_loss'], label='training loss')
plt.plot(history.history['val_disease_output_loss'], label='validation loss')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(fontsize=12)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
plt.title('Disease Loss Curve', fontsize=19)

plt.tight_layout()
plt.show()
